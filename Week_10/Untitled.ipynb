# %%
surveys_complete = pd.read_csv( 'surveys_complete.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3dd73d598a5> in <module>()
# ----> 1 surveys_complete = pd.read_csv( 'surveys_complete.csv', index_col=0)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
from ggplot import *

# %%
surveys_complete = pd.read_csv( 'surveys_complete.csv', index_col=0)

# %%
ggplot( aes(x = 'weight', y = 'hindfoot_length'), data = surveys_complete) + geom_point()
# Out:
# <ggplot: (-9223372036561096602)>
